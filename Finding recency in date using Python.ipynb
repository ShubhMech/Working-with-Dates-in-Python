# %%
path = r"C:\Users\Asus\Desktop\This\P1-UK-Bank-Customers (1).csv"

# %%
import pandas as pd

# %%
stocks= pd.read_csv(path)

# %%
stocks.drop_duplicates('Age', inplace=True)

# %%
(stocks[['Name','Customer ID','Job Classification']].pivot(index='Customer ID', columns='Job Classification')).droplevel(0, axis=1)
# Out:
# Job Classification Blue Collar      Other White Collar
# Customer ID
# 100000001                  NaN        NaN        Simon
# 100000003                  NaN        NaN         Liam
# 100000005              Deirdre        NaN          NaN
# 100000010                  NaN        NaN      Dominic
# 100000011                  NaN        NaN      Dominic
# 100000012                  NaN        NaN     Benjamin
# 100000013                  NaN        NaN         Ryan
# 100000031                  NaN        NaN        Megan
# 100000034                  NaN       Jake          NaN
# 100000041               Edward        NaN          NaN
# 100000045                  NaN    Dorothy          NaN
# 100000051               Sophie        NaN          NaN
# 100000058                  NaN        NaN        Piers
# 100000082                  NaN        NaN         Neil
# 100000096                  NaN        NaN       Joshua
# 200000008                  NaN       Lisa          NaN
# ...

# %%
stocks
# Out:
#       Customer ID       Name    Surname  Gender  Age            Region  \
# 0       100000001      Simon      Walsh    Male   21           England
# 1       400000002    Jasmine     Miller  Female   34  Northern Ireland
# 2       100000003       Liam      Brown    Male   46           England
# 3       300000004     Trevor       Parr    Male   32             Wales
# 4       100000005    Deirdre    Pullman  Female   38           England
# 5       300000006        Ava    Coleman  Female   30             Wales
# 7       200000008       Lisa       Knox  Female   48          Scotland
# 8       300000009       Ruth   Campbell  Female   33             Wales
# 9       100000010    Dominic       Parr    Male   42           England
# 10      100000011    Dominic      Lewis    Male   40           England
# 11      100000012   Benjamin      Grant    Male   39           England
# 12      100000013       Ryan  MacDonald    Male   24           England
# ...

# %%
stocks.set_index(pd.to_datetime(stocks['Date Joined']),inplace=True)

# %%
pd.melt(stocks.pivot(index= 'Customer ID', columns= 'Job Classification'),value_vars='Balance')
# Out:
#         NaN Job Classification      value
# 0   Balance       White Collar  113810.15
# 1   Balance       White Collar  101536.83
# 2   Balance       White Collar        NaN
# 3   Balance       White Collar   10912.45
# 4   Balance       White Collar   39667.83
# 5   Balance       White Collar   32281.62
# 6   Balance       White Collar   40781.63
# 7   Balance       White Collar   38889.76
# 8   Balance       White Collar        NaN
# 9   Balance       White Collar        NaN
# 10  Balance       White Collar        NaN
# 11  Balance       White Collar        NaN
# 12  Balance       White Collar   35831.20
# 13  Balance       White Collar   11624.36
# 14  Balance       White Collar   67479.01
# 15  Balance       White Collar        NaN
# 16  Balance       White Collar        NaN
# 17  Balance       White Collar        NaN
# 18  Balance       White Collar        NaN
# 19  Balance       White Collar        NaN
# 20  Balance       White Collar        NaN
# ...

# %%
stocks.groupby(['Customer ID','Age']).mean()
# Out:
#                    Balance
# Customer ID Age
# 100000001   21   113810.15
# 100000003   46   101536.83
# 100000005   38    35639.79
# 100000010   42    10912.45
# 100000011   40    39667.83
# 100000012   39    32281.62
# 100000013   24    40781.63
# 100000031   25    38889.76
# 100000034   26     5833.62
# 100000041   27    51412.60
# 100000045   53     2893.19
# 100000051   29     1401.43
# 100000058   44    35831.20
# 100000082   20    11624.36
# 100000096   28    67479.01
# 200000008   48    36680.17
# 200000017   31    10356.31
# 200000022   58    21252.97
# 200000024   52     6580.81
# 200000026   55    43249.26
# 200000029   50    20516.10
# 200000039   35    12848.59
# 200000040   59   114456.23
# 200000043   49   114021.21
# 200000046   47    54589.61
# 200000066   43    20076.80
# 200000068   61     7162.43
# 200000070   45    15013.76
# 200000072   51    35937.38
# 200000100   56    13251.27
# 200000104   57    22686.00
# 200000106   54    44973.03
# ...

# %%
(stocks.groupby(['Customer ID','Age']).mean().droplevel(0,axis=0))
# Out:
#        Balance
# Age
# 21   113810.15
# 46   101536.83
# 38    35639.79
# 42    10912.45
# 40    39667.83
# 39    32281.62
# 24    40781.63
# 25    38889.76
# 26     5833.62
# 27    51412.60
# 53     2893.19
# 29     1401.43
# 44    35831.20
# 20    11624.36
# 28    67479.01
# 48    36680.17
# 31    10356.31
# 58    21252.97
# 52     6580.81
# 55    43249.26
# 50    20516.10
# 35    12848.59
# 59   114456.23
# 49   114021.21
# 47    54589.61
# 43    20076.80
# 61     7162.43
# 45    15013.76
# 51    35937.38
# 56    13251.27
# 57    22686.00
# 54    44973.03
# 63    73461.71
# 62    53342.10
# 60     1860.46
# 64    15909.96
# 32     1421.52
# 30   122443.77
# 33    74284.35
# 36     2846.03
# 37    31778.90
# 41    66785.78
# 23     7370.52
# 34    36919.73
# 22   107728.07
# 19    14337.82
# 18    51171.29
# 17    65798.40
# 15    12548.21

# %%
stocks.pivot(index= 'Customer ID', columns= 'Gender', values='Balance')
# Out:
# Gender          Female       Male
# Customer ID
# 100000001          NaN  113810.15
# 100000003          NaN  101536.83
# 100000005     35639.79        NaN
# 100000010          NaN   10912.45
# 100000011          NaN   39667.83
# 100000012          NaN   32281.62
# 100000013          NaN   40781.63
# 100000031     38889.76        NaN
# 100000034          NaN    5833.62
# 100000041          NaN   51412.60
# 100000045      2893.19        NaN
# 100000051      1401.43        NaN
# 100000058          NaN   35831.20
# 100000082          NaN   11624.36
# 100000096          NaN   67479.01
# 200000008     36680.17        NaN
# 200000017     10356.31        NaN
# 200000022          NaN   21252.97
# 200000024          NaN    6580.81
# 200000026          NaN   43249.26
# 200000029          NaN   20516.10
# 200000039          NaN   12848.59
# 200000040          NaN  114456.23
# 200000043          NaN  114021.21
# 200000046     54589.61        NaN
# 200000066          NaN   20076.80
# ...

# %%
(((pd.melt(stocks.pivot(index= 'Customer ID', columns= 'Gender', values='Balance'),var_name='Gender',value_name="Balance")).dropna())).sort_values('Gender')
# Out:
#     Gender    Balance
# 2   Female   35639.79
# 48  Female   12548.21
# 47  Female   65798.40
# 46  Female   51171.29
# 45  Female   14337.82
# 44  Female  107728.07
# 42  Female    7370.52
# 41  Female   66785.78
# 39  Female    2846.03
# 38  Female   74284.35
# 37  Female  122443.77
# 43  Female   36919.73
# 30  Female   22686.00
# 29  Female   13251.27
# 28  Female   35937.38
# 24  Female   54589.61
# 16  Female   10356.31
# 15  Female   36680.17
# 11  Female    1401.43
# 10  Female    2893.19
# 7   Female   38889.76
# 31  Female   44973.03
# 70    Male   12848.59
# 71    Male  114456.23
# 72    Male  114021.21
# 74    Male   20076.80
# 75    Male    7162.43
# 84    Male   15909.96
# 81    Male   73461.71
# 82    Male   53342.10
# 83    Male    1860.46
# 69    Male   20516.10
# 76    Male   15013.76
# 68    Male   43249.26
# 52    Male   10912.45
# 66    Male   21252.97
# 63    Male   67479.01
# 62    Male   11624.36
# 61    Male   35831.20
# 58    Male   51412.60
# ...

# %%
((stocks[['Gender', 'Balance']]).sort_values('Gender'))
# Out:
#              Gender    Balance
# Date Joined
# 2015-10-15   Female   12548.21
# 2015-02-03   Female   54589.61
# 2015-02-03   Female    2893.19
# 2015-02-01   Female  107728.07
# 2015-02-12   Female   35937.38
# 2015-01-28   Female   38889.76
# 2015-03-15   Female    7370.52
# 2015-01-18   Female   66785.78
# 2015-02-08   Female   14337.82
# 2015-03-16   Female   22686.00
# 2015-01-14   Female   10356.31
# 2015-01-12   Female    2846.03
# 2015-03-16   Female   13251.27
# 2015-01-09   Female   35639.79
# 2015-01-06   Female   36919.73
# 2015-03-16   Female   44973.03
# 2015-01-09   Female  122443.77
# 2015-01-11   Female   36680.17
# 2015-02-12   Female    1401.43
# 2015-01-11   Female   74284.35
# 2015-05-03   Female   65798.40
# 2015-03-16   Female   51171.29
# 2015-03-16     Male   67479.01
# 2015-02-12     Male   15013.76
# 2015-02-12     Male    7162.43
# 2015-02-12     Male   20076.80
# 2015-02-12     Male   35831.20
# 2015-05-05     Male   53342.10
# ...

# %%
import datetime as dta

# %%
stocks_= pd.read_csv(path)

# %%
pd.to_datetime(stocks_['Date Joined']).dt.day
# Out:
# 0        5
# 1        6
# 2        7
# 3        8
# 4        9
#         ..
# 4009    30
# 4010    30
# 4011    30
# 4012    30
# 4013    30
# Name: Date Joined, Length: 4014, dtype: int64

# %%
pd.to_datetime(stocks_['Date Joined']).dt.year
# Out:
# 0       2015
# 1       2015
# 2       2015
# 3       2015
# 4       2015
#         ...
# 4009    2015
# 4010    2015
# 4011    2015
# 4012    2015
# 4013    2015
# Name: Date Joined, Length: 4014, dtype: int64

# %%
pd.to_datetime(stocks_['Date Joined']).dt.month
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 4009    12
# 4010    12
# 4011    12
# 4012    12
# 4013    12
# Name: Date Joined, Length: 4014, dtype: int64

# %%
pd.to_datetime(stocks_['Date Joined']).dt.week
# Out:
# <ipython-input-57-7190f053bef8>:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   pd.to_datetime(stocks_['Date Joined']).dt.week
# 0        2
# 1        2
# 2        2
# 3        2
# 4        2
#         ..
# 4009    53
# 4010    53
# 4011    53
# 4012    53
# 4013    53
# Name: Date Joined, Length: 4014, dtype: int64

# %%
pd.to_datetime(stocks_['Date Joined']).dt.strftime('%B %Y')
# Out:
# 0        January 2015
# 1        January 2015
# 2        January 2015
# 3        January 2015
# 4        January 2015
#             ...
# 4009    December 2015
# 4010    December 2015
# 4011    December 2015
# 4012    December 2015
# 4013    December 2015
# Name: Date Joined, Length: 4014, dtype: object

# %%
dta.date(2022,1,23)-dta.date(2017,4,8)
# Out:
# datetime.timedelta(days=1751)

# %%
dta.datetime.today()
# Out:
# datetime.datetime(2022, 1, 23, 21, 58, 44, 522892)

# %%
stocks_.set_index(['Date Joined'], inplace= True)

# %%
stocks_['Date Joined']= pd.to_datetime(stocks_['Date Joined'])

# %%
stocks_.groupby('Name').max()
# Out:
#          Customer ID  Surname  Gender  Age   Region Job Classification  \
# Name
# Abigail    400003443   Wright  Female   64    Wales       White Collar
# Adam       400002151   Wilson    Male   61    Wales       White Collar
# Adrian     400002569   Wright    Male   55    Wales       White Collar
# Alan       300001843   Wright    Male   64    Wales       White Collar
# Alberto    100003789   Mathis    Male   33  England       White Collar
# ...              ...      ...     ...  ...      ...                ...
# Warren     300002728   Walker    Male   62    Wales       White Collar
# Wendy      400001981   Watson  Female   57    Wales       White Collar
# William    400000720  Wilkins    Male   61    Wales       White Collar
# Yvonne     400003009   Wilson  Female   64    Wales       White Collar
# Zoe        400002585    Young  Female   60    Wales       White Collar
#
#         Date Joined    Balance
# Name
# Abigail  2015-12-23   99557.72
# Adam     2015-12-18  124232.17
# ...

# %%
stocks_['Date Joined'].max()- stocks_.groupby('Name')['Date Joined'].max()
# Out:
# Name
# Abigail    7 days
# Adam      12 days
# Adrian    17 days
# Alan      27 days
# Alberto   13 days
#             ...
# Warren    23 days
# Wendy      7 days
# William    7 days
# Yvonne     7 days
# Zoe       30 days
# Name: Date Joined, Length: 172, dtype: timedelta64[ns]

# %%
stocks_
# Out:
#       Customer ID       Name   Surname  Gender  Age            Region  \
# 0       100000001      Simon     Walsh    Male   21           England
# 1       400000002    Jasmine    Miller  Female   34  Northern Ireland
# 2       100000003       Liam     Brown    Male   46           England
# 3       300000004     Trevor      Parr    Male   32             Wales
# 4       100000005    Deirdre   Pullman  Female   38           England
# ...           ...        ...       ...     ...  ...               ...
# 4009    200004010        Sam     Lewis    Male   64          Scotland
# 4010    200004011      Keith    Hughes    Male   52          Scotland
# 4011    200004012     Hannah  Springer  Female   50          Scotland
# 4012    200004013  Christian      Reid    Male   51          Scotland
# 4013    300004014    Stephen       May    Male   33             Wales
#
#      Job Classification Date Joined    Balance
# 0          White Collar  2015-01-05  113810.15
# ...

# %%
str1= "31.Jul.15"
str2= "31.Aug.14"

# %%
str2>str1
# Out:
# False
